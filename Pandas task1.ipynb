# %%
import pandas as pd
import numpy as np
from numpy.random import randint
import matplotlib.pyplot as plt
import seaborn as sns

# %%
da = pd.read_csv('dataset_nan.csv',sep=',',encoding = 'utf-8')

# %%
da
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            NaN     Yes         No     NaN
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
sns.catplot(data=da, kind='count',x='Churn')

# %%
da.fillna(value="0")
# Out:
#       customerID  gender SeniorCitizen Partner Dependents tenure PhoneService  \
# 0     7590-VHVEG  Female             0     Yes         No      0           No
# 1     5575-GNVDE    Male             0      No         No   34.0          Yes
# 2     3668-QPYBK    Male             0      No         No    2.0          Yes
# 3     7795-CFOCW    Male             0      No         No   45.0           No
# 4     9237-HQITU  Female             0      No         No    2.0          Yes
# ...          ...     ...           ...     ...        ...    ...          ...
# 7038  6840-RESVB    Male           0.0     Yes        Yes   24.0          Yes
# 7039  2234-XADUH  Female           0.0     Yes        Yes   72.0          Yes
# 7040  4801-JZAZL  Female           0.0     Yes        Yes   11.0           No
# 7041  8361-LTMKD    Male           1.0     Yes         No    4.0          Yes
# 7042  3186-AJIEK    Male           0.0      No         No   66.0          Yes
#
# ...

# %%
sns.catplot(data=da, kind='count',x='gender',hue='Churn')

# %%
Churn_yes=data[data['Churn']=='Yes']
Churn_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# 5     9305-CDSKC  Female            NaN      No         No     8.0
# 8     7892-POOKP  Female            NaN     Yes         No    28.0
# 13    0280-XJGEX    Male            NaN      No         No    49.0
# ...          ...     ...            ...     ...        ...     ...
# 7021  1699-HPSBG    Male            0.0      No         No    12.0
# 7026  8775-CEBBJ  Female            0.0      No         No     9.0
# 7032  6894-LFHLY    Male            1.0      No         No     1.0
# 7034  0639-TSIQW  Female            0.0      No         No    67.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes            No             DSL            Yes  ...
# ...

# %%
da.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7000.000000  6896.000000     7043.000000   7043.000000
# mean        0.163143    33.041473       64.761692   2283.300440
# std         0.369522    24.382260       30.090047   2265.000258
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000    10.000000       35.500000    402.225000
# 50%         0.000000    30.000000       70.350000   1400.550000
# 75%         0.000000    56.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
Churn_sample= da.sort_values('Churn')
Churn_sample.tail(2000)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2454  5406-KGRMX  Female            0.0      No         No    71.0
# 1937  0854-UYHZD  Female            0.0     Yes        Yes    13.0
# 2533  5397-NSKQG    Male            0.0     Yes        Yes    67.0
# 2874  8347-GDTMP  Female            0.0     Yes         No    64.0
# 2458  7516-GMHUV    Male            1.0     Yes         No    50.0
# ...          ...     ...            ...     ...        ...     ...
# 5441  3512-IZIKN  Female            0.0     Yes         No    70.0
# 1161  5868-CZJDR    Male            0.0      No        Yes     NaN
# 1159  4086-YQSNZ  Female            1.0     Yes         No     3.0
# 1163  0135-NMXAP  Female            0.0      No         No    12.0
# 2974  1481-ZUWZA    Male            0.0      No         No    28.0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 2454          Yes               Yes              No  No internet service  ...
# ...

# %%
Churn_sample.tail(50)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5388  5515-IDEJJ    Male            0.0     Yes        Yes     1.0
# 5385  0843-WTBXE    Male            0.0      No         No    53.0
# 1202  3927-NLNRY    Male            0.0     Yes         No    53.0
# 5383  2362-IBOOY    Male            0.0      No         No    36.0
# 3868  1396-QWFBJ  Female            0.0     Yes        Yes    21.0
# 5381  9465-RWMXL    Male            0.0     Yes         No    32.0
# 5380  9689-PTNPG    Male            0.0      No         No     2.0
# 2324  2774-LVQUS  Female            1.0     Yes         No    15.0
# 1205  6358-LYNGM    Male            0.0      No         No     NaN
# 2323  8949-JTMAY  Female            0.0      No         No    29.0
# 3871  5299-SJCZT    Male            0.0      No         No     3.0
# 5375  9637-EIHEQ  Female            0.0      No         No     1.0
# 5374  8065-YKXKD  Female            0.0      No         No    10.0
# ...

# %%
sns.catplot(data=Churn_sample, kind='count',x='Contract')
## Most of the Churn Customers are using month to month method ,
## so we need to bulid the long erm methods with them

# %%
sns.catplot(data=Churn_sample, kind='count',x='SeniorCitizen')

## Most of the Churn Customers are not Senior Citizen

# %%
sns.distplot(da['tenure'])
# Out:
# C:\Users\georg\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tenure', ylabel='Density'>

# %%
da.fillna(value="0")
# Out:
#       customerID  gender SeniorCitizen Partner Dependents tenure PhoneService  \
# 0     7590-VHVEG  Female             0     Yes         No      0           No
# 1     5575-GNVDE    Male             0      No         No   34.0          Yes
# 2     3668-QPYBK    Male             0      No         No    2.0          Yes
# 3     7795-CFOCW    Male             0      No         No   45.0           No
# 4     9237-HQITU  Female             0      No         No    2.0          Yes
# ...          ...     ...           ...     ...        ...    ...          ...
# 7038  6840-RESVB    Male           0.0     Yes        Yes   24.0          Yes
# 7039  2234-XADUH  Female           0.0     Yes        Yes   72.0          Yes
# 7040  4801-JZAZL  Female           0.0     Yes        Yes   11.0           No
# 7041  8361-LTMKD    Male           1.0     Yes         No    4.0          Yes
# 7042  3186-AJIEK    Male           0.0      No         No   66.0          Yes
#
# ...

# %%
sns.boxplot(x='tenure',y='Churn',data=da)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Churn'>

# %%
sns.lineplot('tenure','Churn',data=da)

## Churn probability is decreasing when tenure become longer
# Out:
# C:\Users\georg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tenure', ylabel='Churn'>

# %%
da2=da.corr()
da2
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen        1.000000  0.013521        0.221101      0.102831
# tenure               0.013521  1.000000        0.238635      0.822171
# MonthlyCharges       0.221101  0.238635        1.000000      0.650468
# TotalCharges         0.102831  0.822171        0.650468      1.000000

# %%
da3=da.replace(['Yes','No'],[1,2])

# %%
da3
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female            NaN        1           2     NaN
# 1     5575-GNVDE    Male            NaN        2           2    34.0
# 2     3668-QPYBK    Male            NaN        2           2     2.0
# 3     7795-CFOCW    Male            NaN        2           2    45.0
# 4     9237-HQITU  Female            NaN        2           2     2.0
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB    Male            0.0        1           1    24.0
# 7039  2234-XADUH  Female            0.0        1           1    72.0
# 7040  4801-JZAZL  Female            0.0        1           1    11.0
# 7041  8361-LTMKD    Male            1.0        1           2     4.0
# 7042  3186-AJIEK    Male            0.0        2           2    66.0
#
#       PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
da3.corr()
# Out:
#                   SeniorCitizen   Partner  Dependents    tenure  PhoneService  \
# SeniorCitizen          1.000000 -0.016189    0.211728  0.013521     -0.008642
# Partner               -0.016189  1.000000    0.452676 -0.374507      0.017706
# Dependents             0.211728  0.452676    1.000000 -0.160442     -0.001762
# tenure                 0.013521 -0.374507   -0.160442  1.000000     -0.005619
# PhoneService          -0.008642  0.017706   -0.001762 -0.005619      1.000000
# PaperlessBilling      -0.156808 -0.014877   -0.111377  0.000328      0.016505
# MonthlyCharges         0.221101 -0.096848    0.113890  0.238635     -0.247398
# TotalCharges           0.102831 -0.318812   -0.064535  0.822171     -0.112851
# Churn                 -0.151711 -0.150448   -0.164221  0.347223      0.011942
#
#                   PaperlessBilling  MonthlyCharges  TotalCharges     Churn
# SeniorCitizen            -0.156808        0.221101      0.102831 -0.151711
# ...

# %%
sns.heatmap(da3.corr(),cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
sns.catplot(data=Churn_sample, kind='count',x='PhoneService')
## Most of the Churn Customers are using phone services

# %%
sns.catplot(data=Churn_sample, kind='count',x='DeviceProtection')
## Most of the Churn Customers don't have device protection
